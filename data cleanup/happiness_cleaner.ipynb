# %%
import pandas as pd
import numpy as np
from pathlib import Path

# %%
#read in dataset and create corresponding dataframe
happiness_csv = Path("C:\\Users\\relam\\Downloads\\DataForTable2.1 modified.csv")
happiness_df = pd.read_csv(happiness_csv)
happiness_df
# Out:
#      Country name  year  Life Ladder  Log GDP per capita  Social support  \
# 0     Afghanistan  2008     3.723590            7.302574        0.450662
# 1     Afghanistan  2009     4.401778            7.472446        0.552308
# 2     Afghanistan  2010     4.758381            7.579183        0.539075
# 3     Afghanistan  2011     3.831719            7.552006        0.521104
# 4     Afghanistan  2012     3.782938            7.637953        0.520637
# ...           ...   ...          ...                 ...             ...
# 2084     Zimbabwe  2017     3.638300            8.241609        0.754147
# 2085     Zimbabwe  2018     3.616480            8.274620        0.775388
# 2086     Zimbabwe  2019     2.693523            8.196998        0.759162
# 2087     Zimbabwe  2020     3.159802            8.117733        0.717243
# 2088     Zimbabwe  2021     3.154578            8.153248        0.685151
#
#       Healthy life expectancy at birth  Freedom to make life choices  \
# ...

# %%
# Drop NaN values from dataframe
happiness_df = happiness_df.dropna()
happiness_df.tail()
# Out:
#      Country name  year  Life Ladder  Log GDP per capita  Social support  \
# 2084     Zimbabwe  2017     3.638300            8.241609        0.754147
# 2085     Zimbabwe  2018     3.616480            8.274620        0.775388
# 2086     Zimbabwe  2019     2.693523            8.196998        0.759162
# 2087     Zimbabwe  2020     3.159802            8.117733        0.717243
# 2088     Zimbabwe  2021     3.154578            8.153248        0.685151
#
#       Healthy life expectancy at birth  Freedom to make life choices  \
# 2084                           0.52150                      0.752826
# 2085                           0.52625                      0.762675
# 2086                           0.53100                      0.631908
# 2087                           0.53575                      0.643303
# 2088                           0.54050                      0.667636
#
#       Generosity  Perceptions of corruption  Positive affect  Negative affect  \
# ...

# %%
# printing dataframe with NaN values removed
print('\happiness_df:')
print(happiness_df)
# Out:
# \happiness_df:
#      Country name  year  Life Ladder  Log GDP per capita  Social support  \
# 0     Afghanistan  2008     3.723590            7.302574        0.450662
# 1     Afghanistan  2009     4.401778            7.472446        0.552308
# 2     Afghanistan  2010     4.758381            7.579183        0.539075
# 3     Afghanistan  2011     3.831719            7.552006        0.521104
# 4     Afghanistan  2012     3.782938            7.637953        0.520637
# ...           ...   ...          ...                 ...             ...
# 2084     Zimbabwe  2017     3.638300            8.241609        0.754147
# 2085     Zimbabwe  2018     3.616480            8.274620        0.775388
# 2086     Zimbabwe  2019     2.693523            8.196998        0.759162
# 2087     Zimbabwe  2020     3.159802            8.117733        0.717243
# 2088     Zimbabwe  2021     3.154578            8.153248        0.685151
#
#       Healthy life expectancy at birth  Freedom to make life choices  \
# ...

# %%
# writing cleaned DF to CSV file
happiness_df.to_csv('cleanedHappiness.csv', index=False)

# %%
# showing file was made by reading it back in
happinessdf_from_csv = pd.read_csv('cleanedHappiness.csv')
print(happinessdf_from_csv)
# Out:
#      Country name  year  Life Ladder  Log GDP per capita  Social support  \
# 0     Afghanistan  2008     3.723590            7.302574        0.450662
# 1     Afghanistan  2009     4.401778            7.472446        0.552308
# 2     Afghanistan  2010     4.758381            7.579183        0.539075
# 3     Afghanistan  2011     3.831719            7.552006        0.521104
# 4     Afghanistan  2012     3.782938            7.637953        0.520637
# ...           ...   ...          ...                 ...             ...
# 1742     Zimbabwe  2017     3.638300            8.241609        0.754147
# 1743     Zimbabwe  2018     3.616480            8.274620        0.775388
# 1744     Zimbabwe  2019     2.693523            8.196998        0.759162
# 1745     Zimbabwe  2020     3.159802            8.117733        0.717243
# 1746     Zimbabwe  2021     3.154578            8.153248        0.685151
#
#       Healthy life expectancy at birth  Freedom to make life choices  \
# ...
